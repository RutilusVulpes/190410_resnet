# %% [markdown]
# # Resnet
#
# ## Please watch Ng C4W2L01-C4W2L04, the first of which is found [here](https://www.youtube.com/watch?v=-bvTzZCEOdM&list=PLkDaE6sCZn6Gl29AoE31iwdVwSG-KnDzF&index=12).
#
# The convolutional neural network that we developed and ran was adequate for use on a small problem with a few classes, but it lacks the explanatory power to produce highly accurate results for more difficult datasets.  Instead, more interesting neural networks have been developed which have greater explanatory power.  One of the most powerful architectures today is called ResNet, which is short for residual network.
#
# In principle, you could take the network that you've been working on and make it more flexible by adding more convolutional layers, which is to say that we could add more sequences of feature map generation.  This is what is meant when people use the term "deep" learning.  However, if you did this, you would quickly run into the problem that your network would struggle to learn weights in the lower (closer to the inputs) layers of the network.  This is a result of the way that neural networks are trained.  In particular they rely on the ability to take the derivative of a misfit function (e.g. least squares) with respect to a parameter, and to adjust the weight based on that derivative.  However in (naive) deep networks, this gradient has the tendency to become negligibly small as the impact of that weight gets lost in the myriad layers of convolutions and activations closer to the output.
#
# ResNet solves this problem by ensuring that the information in each weight gets propagated to the output.  It does this by simply adding the layer's input to each layer's output, so instead of
# $$
# \mathbf{x}_{l+1} = \mathcal{F}_{l}(\mathbf{x}_l),
# $$
# at each layer, the neural network performs the operation
# $$
# \mathbf{x}_{l+1} = \mathcal{F}_{l}(\mathbf{x}_l) + \mathbf{x}_l.
# $$
# Rearranging this equation, we can see why this architecture is called a residual network:
# $$
# \mathbf{x}_{l+1} - \mathbf{x}_l = \mathcal{F}_{l}(\mathbf{x}_l).
# $$
# Each layer is modeling the residual between consecutive feature maps.  The pedantic amongst us will note that this only works when the output of $\mathcal{F}_{l}(\mathbf{x}_l)$ is the same size as the input.  This is dealt with by performing a suitable linear transformation on $\mathbf{x}_l$, making the equation
# $$
# \mathbf{x}_{l+1} = \mathcal{F}_{l}(\mathbf{x}_l) + W \mathbf{x}_l,
# $$
# where $W$ is a matrix that has learnable weights.  The matrix $W$ is most often formulated as a convolution with a 1x1 kernel size.
#
# The addition of the input is known as a *skip connection* because it looks like this:
# <img src=res_net.svg width=600/>
# The input is run through a normal conv layer (perhaps several) and then added to the output, where it can then be maxpooled or run through an activation or whatever.
#
# Keras makes these sorts of networks pretty easy to program.  To start with, let's apply this network to the CIFAR-10 classification problem, but we'll do it for all 10 classes.  All the non-model definition code should look the same as our previous example.

# %%
# Source: https://stackoverflow.com/questions/47286441/only-import-keras-takes-10gb-in-gpu
# This added cell fixes an issue with keras loading onto the gpu's RAM preventing larger batch sizes
# and more complicated models.

import tensorflow as tf
gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.2)
sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
from keras import backend as K
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.2
session = tf.Session(config=config)
K.set_session(session)

# GPU confirmation
from tensorflow.python.client import device_lib
print(str(device_lib.list_local_devices()))
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15032564760159276259
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 1288490188
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1871509369643646625
# physical_device_desc: "device: 0, name: GeForce GTX 980 Ti, pci bus id: 0000:01:00.0, compute capability: 5.2"
# ]

# %%
import keras
import keras.datasets as kd

(x_train, y_train), (x_test, y_test) = kd.cifar10.load_data()
labels = ['airplane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

x_train = x_train/255.
x_test = x_test/255.

# Convert class vectors to binary class matrices.
N = len(labels)

y_train = keras.utils.to_categorical(y_train, N)
y_test = keras.utils.to_categorical(y_test, N)

# %% [markdown]
# Now things get more interesting.  Obviously, ResNet as described above is more of a concept than a specific architecture: we'll need to make some more specific design choices.  One good way of doing this is to look at the literature and copy what others have done.  In particular, the [original ResNet Paper](https://arxiv.org/abs/1512.03385) provides an example of ResNet being applied to CIFAR-10 that yielded excellent accuracy (state of the art c. 2015).  Here, we'll emulate their network architecture, which looks like this:
# <img src=cifar_10_res_net.svg width=900/>
# More concretely, the layers of this network up to (and including) the location of the star in the figure above, look like this.

# %%
import keras.layers as kl
import keras.regularizers as kr

# Note the alternative method for model specification: no model.add(.), instead we 
# perform sequential operations on layers, then we will make the resulting model later.

# Specify the shape of the input image
input_shape = x_train.shape[1:]
inputs = kl.Input(shape=input_shape)

# First convolution + BN + act
conv = kl.Conv2D(16,(3,3),padding='same',kernel_regularizer=kr.l2(1e-4))(inputs)
bn = kl.BatchNormalization()(conv)
act1 = kl.Activation('relu')(bn)

# Perform 3 convolution blocks
for i in range(3):
    conv = kl.Conv2D(16,(3,3),padding='same',kernel_regularizer=kr.l2(1e-4))(act1)
    bn = kl.BatchNormalization()(conv)
    act = kl.Activation('relu')(bn)
    
    conv = kl.Conv2D(16,(3,3),padding='same',kernel_regularizer=kr.l2(1e-4))(act)
    bn = kl.BatchNormalization()(conv)

    # Skip layer addition
    skip = kl.add([act1,bn])
    act1 = kl.Activation('relu')(skip)  

# Downsampling with strided convolution
conv = kl.Conv2D(32,(3,3),padding='same',strides=2,kernel_regularizer=kr.l2(1e-4))(act1)
bn = kl.BatchNormalization()(conv)
act = kl.Activation('relu')(bn)
conv = kl.Conv2D(32,(3,3),padding='same',kernel_regularizer=kr.l2(1e-4))(act)
bn = kl.BatchNormalization()(conv)

# Downsampling with strided 1x1 convolution
act1_downsampled = kl.Conv2D(32,(1,1),padding='same',strides=2,kernel_regularizer=kr.l2(1e-4))(act1)
# Downsampling skip layer
skip_downsampled = kl.add([act1_downsampled,bn])
act1 = kl.Activation('relu')(skip_downsampled)

# This final layer is denoted by a star in the above figure
for _ in range(2):
    conv = kl.Conv2D(32, (3, 3), padding="same", kernel_regularizer=kr.l2(1e-4))(act1)
    bn = kl.BatchNormalization()(conv)
    act = kl.Activation('relu')(bn)
    
    conv = kl.Conv2D(32, (3,3), padding='same', kernel_regularizer=kr.l2(1e-4))(act)
    bn = kl.BatchNormalization()(conv)
    
    # Skip layer addition
    skip = kl.add([act1,bn])
    act1 = kl.Activation('relu')(skip)
    
# Downsampling with strided convolution
conv = kl.Conv2D(64, (3,3), padding='same', strides=2, kernel_regularizer=kr.l2(1e-4))(act1)
bn = kl.BatchNormalization()(conv)
act = kl.Activation('relu')(bn)
conv = kl.Conv2D(64, (3,3), padding='same', kernel_regularizer=kr.l2(1e-4))(act)
bn = kl.BatchNormalization()(conv)

# Downsampling with strided 1x1 convolution
act1_downsampled = kl.Conv2D(64,(1,1),padding='same',strides=2,kernel_regularizer=kr.l2(1e-4))(act1)
# Downsampling skip layer
skip_downsampled = kl.add([act1_downsampled,bn])
act1 = kl.Activation('relu')(skip_downsampled)

# This final layer is denoted by a star in the above figure
for _ in range(2):
    conv = kl.Conv2D(64, (3, 3), padding="same", kernel_regularizer=kr.l2(1e-4))(act1)
    bn = kl.BatchNormalization()(conv)
    act = kl.Activation('relu')(bn)
    conv = kl.Conv2D(64, (3,3), padding='same', kernel_regularizer=kr.l2(1e-4))(act)
    bn = kl.BatchNormalization()(conv)
    
    # Skip layer addition
    skip = kl.add([act1,bn])
    act1 = kl.Activation('relu')(skip)
# Out:
# WARNING:tensorflow:From C:\Users\nohbo\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# To ensure that we have the output shape that we expect at this stage, we can look at the shape of act1

# %%
act1
# Out:
# <tf.Tensor 'activation_115/Relu:0' shape=(?, 8, 8, 64) dtype=float32>

# %% [markdown]
# Which is an object of size 16x16x32, the correct size based on our chosen architecture (note the first question mark indicates an unknown number of input images: thus if we ran the model on a single photo, this would be a 1, if we ran it on the entire CIFAR training set at once it would be 50000).  As before, we can use this model for classification by doing global average pooling, then the softmax function.

# %%
gap = kl.GlobalAveragePooling2D()(act1)
bn = kl.BatchNormalization()(gap)
final_dense = kl.Dense(N)(bn)
softmax = kl.Activation('softmax')(final_dense)

# %%
import keras.models as km
model = km.Model(inputs=inputs,outputs=softmax)

# initiate adam optimizer
opt = keras.optimizers.rmsprop(lr=0.001,decay=1e-6)

model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=128,
          epochs=100,
          validation_data
          =(x_test, y_test),
          shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 324s 6ms/step - loss: 1.4761 - acc: 0.4937 - val_loss: 1.7473 - val_acc: 0.4533
# Epoch 2/100
# 50000/50000 [==============================] - 312s 6ms/step - loss:
100
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2187 - acc: 0.9810 - val_loss: 1.4664 - val_acc: 0.7609
# Epoch 92/100
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2192 - acc: 0.9806 - val_loss: 1.3890 - val_acc: 0.7771
# Epoch 93/100
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2176 - acc: 0.9823 - val_loss: 1.8019 - val_acc: 0.7430
# Epoch 94/100
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2188 - acc: 0.9805 - val_loss: 1.3883 - val_acc: 0.7646
# Epoch 95/100
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2170 - acc: 0.9815 - val_loss: 1.9478 - val_acc: 0.7294
# Epoch 96/100
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2179 - acc: 0.9808 - val_loss: 1.7244 - val_acc: 0.7347
# Epoch 97/100
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2173 - acc: 0.9816 - val_loss: 1.6241 - val_acc: 0.7525
# Epoch 98/100
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2145 - acc: 0.9827 - val_loss: 1.6729 - val_acc: 0.7477
# Epoch 99/100
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2152 - acc: 0.9818 - val_loss: 1.5372 - val_acc: 0.7631
# Epoch 100/100
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.2173 - acc: 0.9808 - val_loss: 1.5558 - val_acc: 0.7588

# %% [markdown]
# While the code as is works, it is *not* the complete architecture given in the figure above.  **Implement the remainder of the network, and train the model for 100 epochs.** The complete architecture has quite a few parameters, so you'll definitely want to use a GPU, i.e. run it on the cluster (reference the job script included in this repo).
#
# There are also a few extra tidbits to make this work better.  First, we'll want to checkpoint the model, which is to say that we'll want to save the weights anytime the model improves during the training process.  We can do this easily in Keras with a checkpoint function:

# %%
import keras.callbacks as kc
filepath = './checkpoints'

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = kc.ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
from keras.models import model_from_json

# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %% [markdown]
# Note that these weights can then be loaded into a model on your local machine for more convenient post-processing and visualization of results.  We'll also want to reduce the learning rate as the model reaches an optimal solution.  We can do this with a *learning rate schedule*.

# %%
def lr_schedule(epoch):
    lr = 1e-3
    if epoch > 60:
        lr *= 1e-3
    print('Learning rate: ', lr)
    return lr
lr_scheduler = kc.LearningRateScheduler(lr_schedule)

# %% [markdown]
# We can include these two functions as *callbacks* to the optimizer:

# %%
model.fit(x_train, y_train,
          batch_size=128,
          epochs=100,
          validation_data=(x_test, y_test),
          shuffle=True,
          callbacks=[checkpoint,lr_scheduler])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 309s 6ms/step - loss: 0.2141 - acc: 0.9821 - val_loss: 1.4598 - val_acc: 0.7731
#
# Epoch 00001: val_acc improved from -inf to 0.77310, saving model to ./checkpoints
# Epoch 2/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2146 - acc: 0.9822 - val_loss: 1.7889 - val_acc: 0.7402
#
# Epoch 00002: val_acc did not improve from 0.77310
# Epoch 3/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2161 - acc: 0.9810 - val_loss: 1.3801 - val_acc: 0.7756
#
# Epoch 00003: val_acc improved from 0.77310 to 0.77560, saving model to ./checkpoints
# Epoch 4/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2148 - acc: 0.9814 - val_loss: 1.4761 - val_acc: 0.7733
#
# Epoch 00004: val_acc did not improve from 0.77560
# Epoch 5/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2165 - acc: 0.9811 - val_loss: 1.5456 - val_acc: 0.7623
#
# Epoch 00005: val_acc did not improve from 0.77560
# Epoch 6/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2125 - acc: 0.9817 - val_loss: 1.4109 - val_acc: 0.7792
#
# Epoch 00006: val_acc improved from 0.77560 to 0.77920, saving model to ./checkpoints
# Epoch 7/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2120 - acc: 0.9824 - val_loss: 1.4165 - val_acc: 0.7859
#
# Epoch 00007: val_acc improved from 0.77920 to 0.78590, saving model to ./checkpoints
# Epoch 8/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2139 - acc: 0.9820 - val_loss: 1.3768 - val_acc: 0.7786
#
# Epoch 00008: val_acc did not improve from 0.78590
# Epoch 9/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2119 - acc: 0.9822 - val_loss: 1.3811 - val_acc: 0.7756
#
# Epoch 00009: val_acc did not improve from 0.78590
# Epoch 10/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2100 - acc: 0.9826 - val_loss: 1.4356 - val_acc: 0.7733
#
# Epoch 00010: val_acc did not improve from 0.78590
# Epoch 11/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2127 - acc: 0.9814 - val_loss: 1.3743 - val_acc: 0.7825
#
# Epoch 00011: val_acc did not improve from 0.78590
# Epoch 12/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2103 - acc: 0.9825 - val_loss: 1.4159 - val_acc: 0.7813
#
# Epoch 00012: val_acc did not improve from 0.78590
# Epoch 13/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2085 - acc: 0.9831 - val_loss: 1.7536 - val_acc: 0.7487
#
# Epoch 00013: val_acc did not improve from 0.78590
# Epoch 14/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2090 - acc: 0.9828 - val_loss: 1.3308 - val_acc: 0.7845
#
# Epoch 00014: val_acc did not improve from 0.78590
# Epoch 15/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 309s 6ms/step - loss: 0.2119 - acc: 0.9818 - val_loss: 1.4144 - val_acc: 0.7715
#
# Epoch 00015: val_acc did not improve from 0.78590
# Epoch 16/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2092 - acc: 0.9828 - val_loss: 1.6213 - val_acc: 0.7493
#
# Epoch 00016: val_acc did not improve from 0.78590
# Epoch 17/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2120 - acc: 0.9822 - val_loss: 1.7279 - val_acc: 0.7514
#
# Epoch 00017: val_acc did not improve from 0.78590
# Epoch 18/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2083 - acc: 0.9821 - val_loss: 1.3807 - val_acc: 0.7841
#
# Epoch 00018: val_acc did not improve from 0.78590
# Epoch 19/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2103 - acc: 0.9823 - val_loss: 1.6751 - val_acc: 0.7397
#
# Epoch 00019: val_acc did not improve from 0.78590
# Epoch 20/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.2107 - acc: 0.9816 - val_loss: 1.4706 - val_acc: 0.7786
#
# Epoch 00020: val_acc did not improve from 0.78590
# Epoch 21/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.2060 - acc: 0.9837 - val_loss: 1.5943 - val_acc: 0.7532
#
# Epoch 00021: val_acc did not improve from 0.78590
# Epoch 22/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.2097 - acc: 0.9830 - val_loss: 1.4369 - val_acc: 0.7723
#
# Epoch 00022: val_acc did not improve from 0.78590
# Epoch 23/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.2087 - acc: 0.9824 - val_loss: 1.6968 - val_acc: 0.7464
#
# Epoch 00023: val_acc did not improve from 0.78590
# Epoch 24/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.2077 - acc: 0.9827 - val_loss: 1.4872 - val_acc: 0.7739
#
# Epoch 00024: val_acc did not improve from 0.78590
# Epoch 25/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2085 - acc: 0.9825 - val_loss: 1.5616 - val_acc: 0.7567
#
# Epoch 00025: val_acc did not improve from 0.78590
# Epoch 26/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2074 - acc: 0.9830 - val_loss: 1.3648 - val_acc: 0.7842
#
# Epoch 00026: val_acc did not improve from 0.78590
# Epoch 27/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2096 - acc: 0.9817 - val_loss: 1.5029 - val_acc: 0.7767
#
# Epoch 00027: val_acc did not improve from 0.78590
# Epoch 28/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2051 - acc: 0.9834 - val_loss: 1.4177 - val_acc: 0.7810
#
# Epoch 00028: val_acc did not improve from 0.78590
# Epoch 29/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2056 - acc: 0.9830 - val_loss: 1.4064 - val_acc: 0.7815
#
# Epoch 00029: val_acc did not improve from 0.78590
# Epoch 30/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2083 - acc: 0.9824 - val_loss: 1.3649 - val_acc: 0.7842
#
# Epoch 00030: val_acc did not improve from 0.78590
# Epoch 31/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2048 - acc: 0.9831 - val_loss: 1.4054 - val_acc: 0.7747
#
# Epoch 00031: val_acc did not improve from 0.78590
# Epoch 32/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2061 - acc: 0.9822 - val_loss: 1.4748 - val_acc: 0.7608
#
# Epoch 00032: val_acc did not improve from 0.78590
# Epoch 33/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2072 - acc: 0.9827 - val_loss: 1.7380 - val_acc: 0.7520
#
# Epoch 00033: val_acc did not improve from 0.78590
# Epoch 34/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2048 - acc: 0.9835 - val_loss: 1.7640 - val_acc: 0.7514
#
# Epoch 00034: val_acc did not improve from 0.78590
# Epoch 35/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.2052 - acc: 0.9830 - val_loss: 1.6812 - val_acc: 0.7370
#
# Epoch 00035: val_acc did not improve from 0.78590
# Epoch 36/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.2050 - acc: 0.9827 - val_loss: 1.3699 - val_acc: 0.7904
#
# Epoch 00036: val_acc improved from 0.78590 to 0.79040, saving model to ./checkpoints
# Epoch 37/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.2042 - acc: 0.9826 - val_loss: 2.4429 - val_acc: 0.6941
#
# Epoch 00037: val_acc did not improve from 0.79040
# Epoch 38/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.2042 - acc: 0.9828 - val_loss: 1.3881 - val_acc: 0.7832
#
# Epoch 00038: val_acc did not improve from 0.79040
# Epoch 39/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.2047 - acc: 0.9830 - val_loss: 1.6216 - val_acc: 0.7539
#
# Epoch 00039: val_acc did not improve from 0.79040
# Epoch 40/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2036 - acc: 0.9830 - val_loss: 1.7821 - val_acc: 0.7282
#
# Epoch 00040: val_acc did not improve from 0.79040
# Epoch 41/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.2036 - acc: 0.9836 - val_loss: 1.4665 - val_acc: 0.7822
#
# Epoch 00041: val_acc did not improve from 0.79040
# Epoch 42/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2063 - acc: 0.9823 - val_loss: 2.0454 - val_acc: 0.7381
#
# Epoch 00042: val_acc did not improve from 0.79040
# Epoch 43/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2015 - acc: 0.9835 - val_loss: 1.3898 - val_acc: 0.7977
#
# Epoch 00043: val_acc improved from 0.79040 to 0.79770, saving model to ./checkpoints
# Epoch 44/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2022 - acc: 0.9834 - val_loss: 1.2947 - val_acc: 0.8022
#
# Epoch 00044: val_acc improved from 0.79770 to 0.80220, saving model to ./checkpoints
# Epoch 45/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2014 - acc: 0.9836 - val_loss: 2.0440 - val_acc: 0.7018
#
# Epoch 00045: val_acc did not improve from 0.80220
# Epoch 46/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2024 - acc: 0.9827 - val_loss: 1.6812 - val_acc: 0.7622
#
# Epoch 00046: val_acc did not improve from 0.80220
# Epoch 47/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2016 - acc: 0.9836 - val_loss: 1.8359 - val_acc: 0.7221
#
# Epoch 00047: val_acc did not improve from 0.80220
# Epoch 48/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2022 - acc: 0.9836 - val_loss: 1.3788 - val_acc: 0.7885
#
# Epoch 00048: val_acc did not improve from 0.80220
# Epoch 49/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2021 - acc: 0.9838 - val_loss: 1.5519 - val_acc: 0.7702
#
# Epoch 00049: val_acc did not improve from 0.80220
# Epoch 50/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2035 - acc: 0.9831 - val_loss: 1.6124 - val_acc: 0.7693
#
# Epoch 00050: val_acc did not improve from 0.80220
# Epoch 51/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2022 - acc: 0.9830 - val_loss: 1.4545 - val_acc: 0.7715
#
# Epoch 00051: val_acc did not improve from 0.80220
# Epoch 52/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2009 - acc: 0.9838 - val_loss: 1.4478 - val_acc: 0.7885
#
# Epoch 00052: val_acc did not improve from 0.80220
# Epoch 53/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2001 - acc: 0.9838 - val_loss: 1.4469 - val_acc: 0.7658
#
# Epoch 00053: val_acc did not improve from 0.80220
# Epoch 54/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1999 - acc: 0.9841 - val_loss: 1.4255 - val_acc: 0.7749
#
# Epoch 00054: val_acc did not improve from 0.80220
# Epoch 55/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.2024 - acc: 0.9829 - val_loss: 1.3846 - val_acc: 0.7853
#
# Epoch 00055: val_acc did not improve from 0.80220
# Epoch 56/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.2011 - acc: 0.9835 - val_loss: 1.3772 - val_acc: 0.7744
#
# Epoch 00056: val_acc did not improve from 0.80220
# Epoch 57/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.2013 - acc: 0.9834 - val_loss: 1.3068 - val_acc: 0.7813
#
# Epoch 00057: val_acc did not improve from 0.80220
# Epoch 58/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.2034 - acc: 0.9832 - val_loss: 1.5913 - val_acc: 0.7468
#
# Epoch 00058: val_acc did not improve from 0.80220
# Epoch 59/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.2014 - acc: 0.9832 - val_loss: 1.4167 - val_acc: 0.7666
#
# Epoch 00059: val_acc did not improve from 0.80220
# Epoch 60/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 306s 6ms/step - loss: 0.1976 - acc: 0.9843 - val_loss: 1.7926 - val_acc: 0.7560
#
# Epoch 00060: val_acc did not improve from 0.80220
# Epoch 61/100
# Learning rate:  0.001
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.2011 - acc: 0.9844 - val_loss: 1.3726 - val_acc: 0.7785
#
# Epoch 00061: val_acc did not improve from 0.80220
# Epoch 62/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1910 - acc: 0.9862 - val_loss: 1.1441 - val_acc: 0.8136
#
# Epoch 00062: val_acc improved from 0.80220 to 0.81360, saving model to ./checkpoints
# Epoch 63/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1884 - acc: 0.9877 - val_loss: 1.1423 - val_acc: 0.8133
#
# Epoch 00063: val_acc did not improve from 0.81360
# Epoch 64/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1852 - acc: 0.9891 - val_loss: 1.1374 - val_acc: 0.8144
#
# Epoch 00064: val_acc improved from 0.81360 to 0.81440, saving model to ./checkpoints
# Epoch 65/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.1851 - acc: 0.9890 - val_loss: 1.1323 - val_acc: 0.8151
#
# Epoch 00065: val_acc improved from 0.81440 to 0.81510, saving model to ./checkpoints
# Epoch 66/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.1830 - acc: 0.9896 - val_loss: 1.1283 - val_acc: 0.8159
#
# Epoch 00066: val_acc improved from 0.81510 to 0.81590, saving model to ./checkpoints
# Epoch 67/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1811 - acc: 0.9904 - val_loss: 1.1229 - val_acc: 0.8162
#
# Epoch 00067: val_acc improved from 0.81590 to 0.81620, saving model to ./checkpoints
# Epoch 68/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1795 - acc: 0.9911 - val_loss: 1.1205 - val_acc: 0.8178
#
# Epoch 00068: val_acc improved from 0.81620 to 0.81780, saving model to ./checkpoints
# Epoch 69/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1777 - acc: 0.9916 - val_loss: 1.1157 - val_acc: 0.8179
#
# Epoch 00069: val_acc improved from 0.81780 to 0.81790, saving model to ./checkpoints
# Epoch 70/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1775 - acc: 0.9918 - val_loss: 1.1149 - val_acc: 0.8175
#
# Epoch 00070: val_acc did not improve from 0.81790
# Epoch 71/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1754 - acc: 0.9929 - val_loss: 1.1107 - val_acc: 0.8187
#
# Epoch 00071: val_acc improved from 0.81790 to 0.81870, saving model to ./checkpoints
# Epoch 72/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1751 - acc: 0.9927 - val_loss: 1.1076 - val_acc: 0.8186
#
# Epoch 00072: val_acc did not improve from 0.81870
# Epoch 73/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1737 - acc: 0.9931 - val_loss: 1.1038 - val_acc: 0.8206
#
# Epoch 00073: val_acc improved from 0.81870 to 0.82060, saving model to ./checkpoints
# Epoch 74/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1730 - acc: 0.9935 - val_loss: 1.1032 - val_acc: 0.8212
#
# Epoch 00074: val_acc improved from 0.82060 to 0.82120, saving model to ./checkpoints
# Epoch 75/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1719 - acc: 0.9938 - val_loss: 1.1007 - val_acc: 0.8212
#
# Epoch 00075: val_acc did not improve from 0.82120
# Epoch 76/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1719 - acc: 0.9938 - val_loss: 1.0982 - val_acc: 0.8215
#
# Epoch 00076: val_acc improved from 0.82120 to 0.82150, saving model to ./checkpoints
# Epoch 77/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1701 - acc: 0.9947 - val_loss: 1.0969 - val_acc: 0.8216
#
# Epoch 00077: val_acc improved from 0.82150 to 0.82160, saving model to ./checkpoints
# Epoch 78/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1695 - acc: 0.9948 - val_loss: 1.0953 - val_acc: 0.8219
#
# Epoch 00078: val_acc improved from 0.82160 to 0.82190, saving model to ./checkpoints
# Epoch 79/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1687 - acc: 0.9954 - val_loss: 1.0922 - val_acc: 0.8218
#
# Epoch 00079: val_acc did not improve from 0.82190
# Epoch 80/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1682 - acc: 0.9955 - val_loss: 1.0907 - val_acc: 0.8224
#
# Epoch 00080: val_acc improved from 0.82190 to 0.82240, saving model to ./checkpoints
# Epoch 81/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1681 - acc: 0.9955 - val_loss: 1.0887 - val_acc: 0.8232
#
# Epoch 00081: val_acc improved from 0.82240 to 0.82320, saving model to ./checkpoints
# Epoch 82/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1672 - acc: 0.9958 - val_loss: 1.0879 - val_acc: 0.8230
#
# Epoch 00082: val_acc did not improve from 0.82320
# Epoch 83/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1664 - acc: 0.9963 - val_loss: 1.0864 - val_acc: 0.8237
#
# Epoch 00083: val_acc improved from 0.82320 to 0.82370, saving model to ./checkpoints
# Epoch 84/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1666 - acc: 0.9961 - val_loss: 1.0848 - val_acc: 0.8241
#
# Epoch 00084: val_acc improved from 0.82370 to 0.82410, saving model to ./checkpoints
# Epoch 85/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.1665 - acc: 0.9959 - val_loss: 1.0836 - val_acc: 0.8247
#
# Epoch 00085: val_acc improved from 0.82410 to 0.82470, saving model to ./checkpoints
# Epoch 86/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1647 - acc: 0.9968 - val_loss: 1.0849 - val_acc: 0.8250
#
# Epoch 00086: val_acc improved from 0.82470 to 0.82500, saving model to ./checkpoints
# Epoch 87/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1656 - acc: 0.9964 - val_loss: 1.0811 - val_acc: 0.8255
#
# Epoch 00087: val_acc improved from 0.82500 to 0.82550, saving model to ./checkpoints
# Epoch 88/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.1645 - acc: 0.9969 - val_loss: 1.0813 - val_acc: 0.8250
#
# Epoch 00088: val_acc did not improve from 0.82550
# Epoch 89/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.1642 - acc: 0.9972 - val_loss: 1.0798 - val_acc: 0.8259
#
# Epoch 00089: val_acc improved from 0.82550 to 0.82590, saving model to ./checkpoints
# Epoch 90/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.1640 - acc: 0.9971 - val_loss: 1.0787 - val_acc: 0.8261
#
# Epoch 00090: val_acc improved from 0.82590 to 0.82610, saving model to ./checkpoints
# Epoch 91/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.1635 - acc: 0.9974 - val_loss: 1.0769 - val_acc: 0.8264
#
# Epoch 00091: val_acc improved from 0.82610 to 0.82640, saving model to ./checkpoints
# Epoch 92/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.1636 - acc: 0.9972 - val_loss: 1.0762 - val_acc: 0.8262
#
# Epoch 00092: val_acc did not improve from 0.82640
# Epoch 93/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.1632 - acc: 0.9975 - val_loss: 1.0751 - val_acc: 0.8260
#
# Epoch 00093: val_acc did not improve from 0.82640
# Epoch 94/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.1621 - acc: 0.9981 - val_loss: 1.0742 - val_acc: 0.8263
#
# Epoch 00094: val_acc did not improve from 0.82640
# Epoch 95/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.1622 - acc: 0.9975 - val_loss: 1.0731 - val_acc: 0.8265
#
# Epoch 00095: val_acc improved from 0.82640 to 0.82650, saving model to ./checkpoints
# Epoch 96/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 307s 6ms/step - loss: 0.1622 - acc: 0.9980 - val_loss: 1.0724 - val_acc: 0.8265
#
# Epoch 00096: val_acc did not improve from 0.82650
# Epoch 97/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1622 - acc: 0.9976 - val_loss: 1.0724 - val_acc: 0.8267
#
# Epoch 00097: val_acc improved from 0.82650 to 0.82670, saving model to ./checkpoints
# Epoch 98/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1613 - acc: 0.9981 - val_loss: 1.0720 - val_acc: 0.8265
#
# Epoch 00098: val_acc did not improve from 0.82670
# Epoch 99/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1610 - acc: 0.9982 - val_loss: 1.0709 - val_acc: 0.8268
#
# Epoch 00099: val_acc improved from 0.82670 to 0.82680, saving model to ./checkpoints
# Epoch 100/100
# Learning rate:  1e-06
# 50000/50000 [==============================] - 308s 6ms/step - loss: 0.1614 - acc: 0.9982 - val_loss: 1.0712 - val_acc: 0.8270
#
# Epoch 00100: val_acc improved from 0.82680 to 0.82700, saving model to ./checkpoints

# %%
def makeCAM(model,imgArray,classIdx):
   
    fig = plt.figure(figsize=(8,8))
    plot_num = 1

    for idx in imgArray:
        last_conv, probs = model.predict(x_train[idx].reshape((1,32,32,3)))
        cam = np.zeros((8,8))
        for i in range(32):
            fm = last_conv[0,:,:,i] # feature map i
            w = final_dense.get_weights()[0][i][classIdx] # weight of feature map i at index 1 (deer)
            cam += fm*w
        cam_upscaled = snd.zoom(cam,4)

        ax = fig.add_subplot(3, 3, plot_num)
        ax.imshow(x_train[idx])
        ax.imshow(cam_upscaled,alpha=0.2,cmap=plt.cm.jet)

        plot_num += 1

# %% [markdown]
# Once your model is fitted, **adapt your class activation mapping routine to run on this more advanced architecture, and compute a few examples?  How do these activation maps differ from those computed for the smaller network?**

# %%
import keras
import keras.datasets as kd

(x_train, y_train), (x_test, y_test) = kd.cifar10.load_data()
labels = ['airplane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

x_train = x_train/255.
x_test = x_test/255.

# Convert class vectors to binary class matrices.
N = len(labels)

y_train = keras.utils.to_categorical(y_train, N)
y_test = keras.utils.to_categorical(y_test, N)

import keras.layers as kl
import keras.regularizers as kr

# Note the alternative method for model specification: no model.add(.), instead we 
# perform sequential operations on layers, then we will make the resulting model later.

# Specify the shape of the input image
input_shape = x_train.shape[1:]
inputs = kl.Input(shape=input_shape)

# First convolution + BN + act
conv = kl.Conv2D(16,(3,3),padding='same',kernel_regularizer=kr.l2(1e-4))(inputs)
bn = kl.BatchNormalization()(conv)
act1 = kl.Activation('relu')(bn)

# Perform 3 convolution blocks
for i in range(3):
    conv = kl.Conv2D(16,(3,3),padding='same',kernel_regularizer=kr.l2(1e-4))(act1)
    bn = kl.BatchNormalization()(conv)
    act = kl.Activation('relu')(bn)
    
    conv = kl.Conv2D(16,(3,3),padding='same',kernel_regularizer=kr.l2(1e-4))(act)
    bn = kl.BatchNormalization()(conv)

    # Skip layer addition
    skip = kl.add([act1,bn])
    act1 = kl.Activation('relu')(skip)  

# Downsampling with strided convolution
conv = kl.Conv2D(32,(3,3),padding='same',strides=2,kernel_regularizer=kr.l2(1e-4))(act1)
bn = kl.BatchNormalization()(conv)
act = kl.Activation('relu')(bn)
conv = kl.Conv2D(32,(3,3),padding='same',kernel_regularizer=kr.l2(1e-4))(act)
bn = kl.BatchNormalization()(conv)

# Downsampling with strided 1x1 convolution
act1_downsampled = kl.Conv2D(32,(1,1),padding='same',strides=2,kernel_regularizer=kr.l2(1e-4))(act1)
# Downsampling skip layer
skip_downsampled = kl.add([act1_downsampled,bn])
act1 = kl.Activation('relu')(skip_downsampled)

# This final layer is denoted by a star in the above figure
for _ in range(2):
    conv = kl.Conv2D(32, (3, 3), padding="same", kernel_regularizer=kr.l2(1e-4))(act1)
    bn = kl.BatchNormalization()(conv)
    act = kl.Activation('relu')(bn)
    
    conv = kl.Conv2D(32, (3,3), padding='same', kernel_regularizer=kr.l2(1e-4))(act)
    bn = kl.BatchNormalization()(conv)
    
    # Skip layer addition
    skip = kl.add([act1,bn])
    act1 = kl.Activation('relu')(skip)
    
# Downsampling with strided convolution
conv = kl.Conv2D(64, (3,3), padding='same', strides=2, kernel_regularizer=kr.l2(1e-4))(act1)
bn = kl.BatchNormalization()(conv)
act = kl.Activation('relu')(bn)
conv = kl.Conv2D(64, (3,3), padding='same', kernel_regularizer=kr.l2(1e-4))(act)
bn = kl.BatchNormalization()(conv)

# Downsampling with strided 1x1 convolution
act1_downsampled = kl.Conv2D(64,(1,1),padding='same',strides=2,kernel_regularizer=kr.l2(1e-4))(act1)
# Downsampling skip layer
skip_downsampled = kl.add([act1_downsampled,bn])
act1 = kl.Activation('relu')(skip_downsampled)

# This final layer is denoted by a star in the above figure
for _ in range(2):
    conv = kl.Conv2D(64, (3, 3), padding="same", kernel_regularizer=kr.l2(1e-4))(act1)
    bn = kl.BatchNormalization()(conv)
    act = kl.Activation('relu')(bn)
    conv = kl.Conv2D(64, (3,3), padding='same', kernel_regularizer=kr.l2(1e-4))(act)
    bn = kl.BatchNormalization()(conv)
    
    # Skip layer addition
    skip = kl.add([act1,bn])
    act1 = kl.Activation('relu')(skip)

gap = kl.GlobalAveragePooling2D()(act1)
bn = kl.BatchNormalization()(gap)
final_dense = kl.Dense(N)(bn)
softmax = kl.Activation('softmax')(final_dense)    
    
    
import keras.models as km
model = km.Model(inputs=inputs,outputs=softmax)

model.load_weights('./checkpoints')

# %%
import numpy as np
import matplotlib.pyplot as plt

labels = ['airplane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
test = 1
probs = model.predict(x_train[test].reshape((1,32,32,3)))
pred = np.argmax(probs)
print('This thing is a: '+ labels[pred])

plt.imshow(x_train[test])

print(probs, new_labels)
# Out:
# This thing is a: frog
# [[6.8558758e-15 7.5004117e-14 7.8903062e-09 1.5524640e-09 2.1040463e-11
#   3.9030892e-12 1.0000000e+00 1.1331576e-14 9.7539359e-13 1.7109869e-13]] ['cat', 'deer', 'ship']

# %%
deer_img = [0, 3, 5, 8, 10, 32]

makeCam(model,deer_array, 4)
